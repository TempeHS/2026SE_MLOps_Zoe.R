# %% [markdown]
# uhhhhhhh model notes
# - uhmmmmmm uhhhh i think risk works better than bmi because theres a stronger correlation i think? (the line is a bit better)
# - cosine graph lookin ass
# - 3 degrees works best in terms of the polynomial (not too over or underfit)
# - would try splitting into subplots but it is 11:54 so -> https://python-graph-gallery.com/194-split-the-graphic-window-with-subplot/ <- tutorial
